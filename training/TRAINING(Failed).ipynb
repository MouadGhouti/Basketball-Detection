# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.5/756.5 kB 14.0 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
# !unzip /content/drive/MyDrive/ComputerVision/bbgame3.zip -d /content/drive/MyDrive/ComputerVision/bbgame3
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/drive/MyDrive/ComputerVision/bbgame3/train/images/img-00059_jpg.rf.d1b1115a2f69796d1ccc75dbe2cd6aba.jpg
#  extracting: /content/drive/MyDrive/ComputerVision/bbgame3/train/images/img-00060_jpg.rf.12773246087605f69c1dc42a97eff2ec.jpg
#  extracting: /content/drive/MyDrive/ComputerVision/bbgame3/train/images/img-00060_jpg.rf.351561a8720fb7a7fb8b8021e3c39b5c.jpg
#  extracting: /content/drive/MyDrive/ComputerVision/bbgame3/train/images/img-00060_jpg.rf.82a2e2d6c6d43a82be3b4e99df56c7e8.jpg
#  extracting: /content/drive/MyDrive/ComputerVision/bbgame3/train/images/img-00060_jpg.rf.b67b63b6622c575eb7e84cbedb8e8a08.jpg
#  extracting: /content/drive/MyDrive/ComputerVision/bbgame3/train/images/img-00060_jpg.rf.bda64efb5f8ed6b741240cb22675a21c.jpg
#  extracting: /content/drive/MyDrive/ComputerVision/bbgame3/train/images/img-00060_jpg.rf.f788d947e346a45937d176bba8e6fb38.jpg
# ...

# %%
import shutil
shutil.move("/content/drive/MyDrive/ComputerVision/bbgame3/train",
"/content/drive/MyDrive/ComputerVision/bbgame3/bbgame3/train",
)
shutil.move("/content/drive/MyDrive/ComputerVision/bbgame3/test",
"/content/drive/MyDrive/ComputerVision/bbgame3/bbgame3/test",
)
shutil.move("/content/drive/MyDrive/ComputerVision/bbgame3/valid",
"/content/drive/MyDrive/ComputerVision/bbgame3/bbgame3/valid",
)
# Out:
# '/content/drive/MyDrive/ComputerVision/bbgame3/bbgame3/valid'

# %%
# !yolo task=detect mode=train data='/content/drive/MyDrive/ComputerVision/bbgame3/data.yaml'save_period=10 plots=True  epochs=60 save_dir=''
# Out:
# Ultralytics YOLOv8.2.11 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Out:
# /bin/bash: -c: line 1: unexpected EOF while looking for matching `''
# /bin/bash: -c: line 2: syntax error: unexpected end of file
